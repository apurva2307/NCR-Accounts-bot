# %%
import pandas as pd
url = "https://docs.google.com/spreadsheets/d/1kXBrVy9mREA1ydLnBrWOxTl0mtfEaZRXi8Q_-IZGYfg/gviz/tq?tqx=out:csv&sheet=10"
df = pd.read_excel("OWE_Nov_21.xlsx", sheet_name="PU Wise OWE", header=2, skiprows=lambda x: x in [14, 26])
# df = pd.read_csv(url)
# df['Demand'] = df['Demand'].fillna("03")
df3 = df.loc[0:10]
df3
# Out:
#    Demand            Particular           Pay             DA           PLB  \
# 0     NaN                   NaN  1.000000e+00       2.000000      3.000000
# 1      03      OBG(SL) 2021-22   2.657920e+06  756706.000000  72518.000000
# 2     NaN     BP to end  Nov-21  1.807386e+06  478044.000000  72518.000000
# 3     NaN  Actuals upto Nov' 20  1.785127e+06  295228.000000  68252.000000
# 4     NaN  Actuals upto Nov' 21  1.759224e+06  441447.000000  66512.000000
# 5     NaN                 AC-BP -4.816200e+04  -36597.000000  -6006.000000
# 6     NaN         % var.over BP -2.664732e-02      -0.076556     -0.082821
# 7     NaN            AC- Coppy  -2.590300e+04  146219.000000  -1740.000000
# 8     NaN     % var. over coppy -1.451045e-02       0.495275     -0.025494
# 9     NaN      % FG Utilization  6.618800e-01       0.583380      0.917179
# 10    NaN               AC - FG  8.986960e+05  315259.000000   6006.000000
#
#               HRA            TPA  NPS  W/CL          KMA  ...  \
# ...

# %%
exp = df.set_index([0,1])
exp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24600/45111904.py in <module>
# ----> 1 exp = df.set_index([0,1])
#       2 exp
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: 'None of [0, 1] are in the columns'
